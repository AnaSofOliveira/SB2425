# %%
pip install biosppy
# Out:
# ...
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/3.0 MB 419.4 kB/s eta 0:00:06
#    ---------- ----------------------------- 0.8/3.0 MB 610.3 kB/s eta 0:00:04
#    -------------- ------------------------- 1.0/3.0 MB 729.5 kB/s eta 0:00:03
#    ----------------- ---------------------- 1.3/3.0 MB 828.3 kB/s eta 0:00:03
#    --------------------- ------------------ 1.6/3.0 MB 892.3 kB/s eta 0:00:02
#    ------------------------ --------------- 1.8/3.0 MB 949.8 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.1/3.0 MB 987.1 kB/s eta 0:00:01
#    ------------------------------- -------- 2.4/3.0 MB 1.0 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import wfdb 
from biosppy.signals import ecg

# %%
record = wfdb.rdrecord('ecg-id-database-1.0.0/Person_01/rec_1') 
wfdb.plot_wfdb(record=record, title='ecg-id-database-1.0.0/Person_06/rec_1') 
display(record.__dict__)
# Out:
# {'record_name': 'rec_1',
#  'n_sig': 2,
#  'fs': 500,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 10000,
#  'base_time': None,
#  'base_date': None,
#  'comments': ['Age: 25', 'Sex: male', 'ECG date: 07.12.2004'],
#  'sig_name': ['ECG I', 'ECG I filtered'],
#  'p_signal': array([[-0.085, -0.115],
#         [-0.08 , -0.115],
#         [-0.07 , -0.12 ],
#         ...,
#         [-0.065, -0.035],
#         [-0.08 , -0.035],
#         [-0.08 , -0.035]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['rec_1.dat', 'rec_1.dat'],
#  'fmt': ['16', '16'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [None, None],
#  'adc_gain': [200.0, 200.0],
#  'baseline': [0, 0],
#  'units': ['mV', 'mV'],
#  'adc_res': [12, 12],
#  'adc_zero': [0, 0],
#  'init_value': [-17, -23],
#  'checksum': [17532, 2004],
#  'block_size': [0, 0]}

# %%
X = record.p_signal
fs = record.fs

# %%
signal = X[:,1] # Get the second channel with filtered data
out = ecg.ecg(signal=signal, sampling_rate=fs, show=True)

# %%
print(out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(out)
#
# NameError: name 'out' is not defined
