# %%
pip install pyPPG==1.0.41
# Out:
# Collecting pyPPG==1.0.41
#   Downloading pyPPG-1.0.41-py3-none-any.whl.metadata (8.0 kB)
# Collecting scipy==1.9.1 (from pyPPG==1.0.41)
#   Downloading scipy-1.9.1-cp310-cp310-win_amd64.whl.metadata (2.2 kB)
# Collecting numpy==1.23.2 (from pyPPG==1.0.41)
#   Downloading numpy-1.23.2-cp310-cp310-win_amd64.whl.metadata (2.2 kB)
# Collecting dotmap==1.3.30 (from pyPPG==1.0.41)
#   Downloading dotmap-1.3.30-py3-none-any.whl.metadata (3.2 kB)
# Collecting pandas==1.4.4 (from pyPPG==1.0.41)
#   Downloading pandas-1.4.4-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting wfdb==3.4.0 (from pyPPG==1.0.41)
#   Downloading wfdb-3.4.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting mne==1.5.0 (from pyPPG==1.0.41)
#   Downloading mne-1.5.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting Eel==0.14.0 (from pyPPG==1.0.41)
#   Downloading Eel-0.14.0.tar.gz (17 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting Jinja2==3.1.2 (from pyPPG==1.0.41)
#   Downloading Jinja2-3.1.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting MarkupSafe==2.1.1 (from pyPPG==1.0.41)
#   Downloading MarkupSafe-2.1.1-cp310-cp310-win_amd64.whl.metadata (3.2 kB)
# Collecting Pillow==9.2.0 (from pyPPG==1.0.41)
#   Downloading Pillow-9.2.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting altgraph==0.17.3 (from pyPPG==1.0.41)
#   Downloading altgraph-0.17.3-py2.py3-none-any.whl.metadata (7.4 kB)
# Collecting appdirs==1.4.4 (from pyPPG==1.0.41)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting attrs==22.1.0 (from pyPPG==1.0.41)
#   Downloading attrs-22.1.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting auto-py-to-exe==2.23.1 (from pyPPG==1.0.41)
#   Downloading auto_py_to_exe-2.23.1-py2.py3-none-any.whl.metadata (11 kB)
# Collecting boltons==21.0.0 (from pyPPG==1.0.41)
#   Downloading boltons-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting bottle==0.12.23 (from pyPPG==1.0.41)
#   Downloading bottle-0.12.23-py3-none-any.whl.metadata (1.8 kB)
# Collecting bottle-websocket==0.2.9 (from pyPPG==1.0.41)
#   Downloading bottle-websocket-0.2.9.tar.gz (2.0 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting certifi==2022.9.24 (from pyPPG==1.0.41)
#   Downloading certifi-2022.9.24-py3-none-any.whl.metadata (2.9 kB)
# Collecting cffi==1.15.1 (from pyPPG==1.0.41)
#   Downloading cffi-1.15.1-cp310-cp310-win_amd64.whl.metadata (1.1 kB)
# Collecting chardet==5.0.0 (from pyPPG==1.0.41)
#   Downloading chardet-5.0.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting charset-normalizer==2.1.1 (from pyPPG==1.0.41)
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting colorama==0.4.5 (from pyPPG==1.0.41)
#   Downloading colorama-0.4.5-py2.py3-none-any.whl.metadata (15 kB)
# Collecting contourpy==1.0.5 (from pyPPG==1.0.41)
#   Downloading contourpy-1.0.5-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Collecting cycler==0.11.0 (from pyPPG==1.0.41)
#   Downloading cycler-0.11.0-py3-none-any.whl.metadata (785 bytes)
# Requirement already satisfied: decorator==5.1.1 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from pyPPG==1.0.41) (5.1.1)
# Collecting dotteddict==2016.3.11 (from pyPPG==1.0.41)
#   Downloading dotteddict-2016.3.11.tar.gz (3.1 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting face==20.1.1 (from pyPPG==1.0.41)
#   Downloading face-20.1.1-py3-none-any.whl.metadata (868 bytes)
# Collecting fonttools==4.37.1 (from pyPPG==1.0.41)
#   Downloading fonttools-4.37.1-py3-none-any.whl.metadata (134 kB)
# Collecting future==0.18.2 (from pyPPG==1.0.41)
#   Downloading future-0.18.2.tar.gz (829 kB)
#      ---------------------------------------- 0.0/829.2 kB ? eta -:--:--
#      -------------------------------------- 829.2/829.2 kB 9.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting gevent==21.12.0 (from pyPPG==1.0.41)
#   Downloading gevent-21.12.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting gevent-websocket==0.10.1 (from pyPPG==1.0.41)
#   Downloading gevent_websocket-0.10.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting glom==22.1.0 (from pyPPG==1.0.41)
#   Downloading glom-22.1.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting greenlet==1.1.3 (from pyPPG==1.0.41)
#   Downloading greenlet-1.1.3-cp310-cp310-win_amd64.whl.metadata (3.9 kB)
# Collecting heartpy==1.2.7 (from pyPPG==1.0.41)
#   Downloading heartpy-1.2.7-py3-none-any.whl.metadata (9.5 kB)
# Collecting idna==3.4 (from pyPPG==1.0.41)
#   Downloading idna-3.4-py3-none-any.whl.metadata (9.8 kB)
# Collecting joblib==1.2.0 (from pyPPG==1.0.41)
#   Downloading joblib-1.2.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting kiwisolver==1.4.4 (from pyPPG==1.0.41)
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Collecting matplotlib==3.6.1 (from pyPPG==1.0.41)
#   Downloading matplotlib-3.6.1-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Collecting mpldatacursor==0.7.1 (from pyPPG==1.0.41)
#   Downloading mpldatacursor-0.7.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting packaging==21.3 (from pyPPG==1.0.41)
#   Downloading packaging-21.3-py3-none-any.whl.metadata (15 kB)
# Collecting parallel-map==0.2.1 (from pyPPG==1.0.41)
#   Downloading parallel_map-0.2.1.tar.gz (4.9 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting patsy==0.5.3 (from pyPPG==1.0.41)
#   Downloading patsy-0.5.3-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting pefile==2022.5.30 (from pyPPG==1.0.41)
#   Downloading pefile-2022.5.30.tar.gz (72 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pip==21.3.1 (from pyPPG==1.0.41)
#   Downloading pip-21.3.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting pooch==1.6.0 (from pyPPG==1.0.41)
#   Downloading pooch-1.6.0-py3-none-any.whl.metadata (10 kB)
# Collecting pycparser==2.21 (from pyPPG==1.0.41)
#   Downloading pycparser-2.21-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting pyinstaller==5.5 (from pyPPG==1.0.41)
#   Downloading pyinstaller-5.5-py3-none-win_amd64.whl.metadata (8.6 kB)
# Collecting pyinstaller-hooks-contrib==2022.10 (from pyPPG==1.0.41)
#   Downloading pyinstaller_hooks_contrib-2022.10-py2.py3-none-any.whl.metadata (16 kB)
# Collecting pyparsing==3.0.9 (from pyPPG==1.0.41)
#   Downloading pyparsing-3.0.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting python-dateutil==2.8.2 (from pyPPG==1.0.41)
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting pytz==2022.4 (from pyPPG==1.0.41)
#   Downloading pytz-2022.4-py2.py3-none-any.whl.metadata (21 kB)
# Collecting pywin32-ctypes==0.2.0 (from pyPPG==1.0.41)
#   Downloading pywin32_ctypes-0.2.0-py2.py3-none-any.whl.metadata (683 bytes)
# Collecting requests==2.28.1 (from pyPPG==1.0.41)
#   Downloading requests-2.28.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting scikit-learn==1.1.3 (from pyPPG==1.0.41)
#   Downloading scikit_learn-1.1.3-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Collecting setuptools==60.2.0 (from pyPPG==1.0.41)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: six==1.16.0 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from pyPPG==1.0.41) (1.16.0)
# Collecting soundfile==0.11.0 (from pyPPG==1.0.41)
#   Downloading soundfile-0.11.0-py2.py3-none-win_amd64.whl.metadata (13 kB)
# Collecting statsmodels==0.13.2 (from pyPPG==1.0.41)
#   Downloading statsmodels-0.13.2-cp310-cp310-win_amd64.whl.metadata (8.1 kB)
# Collecting threadpoolctl==3.1.0 (from pyPPG==1.0.41)
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting tqdm==4.64.1 (from pyPPG==1.0.41)
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl.metadata (57 kB)
# Collecting urllib3==1.26.12 (from pyPPG==1.0.41)
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl.metadata (47 kB)
# Collecting wheel==0.37.1 (from pyPPG==1.0.41)
#   Downloading wheel-0.37.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting whichcraft==0.6.1 (from pyPPG==1.0.41)
#   Downloading whichcraft-0.6.1-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting zope.event==4.5.0 (from pyPPG==1.0.41)
#   Downloading zope.event-4.5.0-py2.py3-none-any.whl.metadata (4.3 kB)
# Collecting zope.interface==5.4.0 (from pyPPG==1.0.41)
#   Downloading zope.interface-5.4.0.tar.gz (249 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Downloading pyPPG-1.0.41-py3-none-any.whl (58 kB)
# Downloading altgraph-0.17.3-py2.py3-none-any.whl (21 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
# Downloading auto_py_to_exe-2.23.1-py2.py3-none-any.whl (97 kB)
# Downloading boltons-21.0.0-py2.py3-none-any.whl (193 kB)
# Downloading bottle-0.12.23-py3-none-any.whl (90 kB)
# Downloading certifi-2022.9.24-py3-none-any.whl (161 kB)
# Downloading cffi-1.15.1-cp310-cp310-win_amd64.whl (179 kB)
# Downloading chardet-5.0.0-py3-none-any.whl (193 kB)
# Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Downloading contourpy-1.0.5-cp310-cp310-win_amd64.whl (164 kB)
# Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Downloading dotmap-1.3.30-py3-none-any.whl (11 kB)
# Downloading face-20.1.1-py3-none-any.whl (51 kB)
# Downloading fonttools-4.37.1-py3-none-any.whl (957 kB)
#    ---------------------------------------- 0.0/957.2 kB ? eta -:--:--
#    ---------------------------------------- 957.2/957.2 kB 7.4 MB/s eta 0:00:00
# Downloading gevent-21.12.0-cp310-cp310-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------------- ------- 1.3/1.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 5.8 MB/s eta 0:00:00
# Downloading gevent_websocket-0.10.1-py3-none-any.whl (22 kB)
# Downloading glom-22.1.0-py2.py3-none-any.whl (100 kB)
# Downloading greenlet-1.1.3-cp310-cp310-win_amd64.whl (101 kB)
# Downloading heartpy-1.2.7-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 9.5 MB/s eta 0:00:00
# Downloading idna-3.4-py3-none-any.whl (61 kB)
# Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
# Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
# Downloading MarkupSafe-2.1.1-cp310-cp310-win_amd64.whl (17 kB)
# Downloading matplotlib-3.6.1-cp310-cp310-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    -------- ------------------------------- 1.6/7.2 MB 7.6 MB/s eta 0:00:01
#    --------------- ------------------------ 2.9/7.2 MB 7.3 MB/s eta 0:00:01
#    --------------------- ------------------ 3.9/7.2 MB 6.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.2/7.2 MB 6.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.2 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 4.6 MB/s eta 0:00:00
# Downloading mne-1.5.0-py3-none-any.whl (7.7 MB)
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/7.7 MB 12.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.7 MB 12.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/7.7 MB 3.6 MB/s eta 0:00:02
#    ------------------- -------------------- 3.7/7.7 MB 4.2 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.7 MB 4.4 MB/s eta 0:00:01
#    --------------------------- ------------ 5.2/7.7 MB 4.7 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.7 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.7 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.7 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.7/7.7 MB 3.9 MB/s eta 0:00:00
# Downloading mpldatacursor-0.7.1-py3-none-any.whl (23 kB)
# Downloading numpy-1.23.2-cp310-cp310-win_amd64.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/14.6 MB 10.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.6 MB 9.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.0/14.6 MB 9.7 MB/s eta 0:00:01
#    -------------------- ------------------- 7.6/14.6 MB 9.2 MB/s eta 0:00:01
#    --------------------------- ------------ 10.0/14.6 MB 9.4 MB/s eta 0:00:01
#    ------------------------------- -------- 11.5/14.6 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.6 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 8.9 MB/s eta 0:00:00
# Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Downloading pandas-1.4.4-cp310-cp310-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/10.0 MB 10.1 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/10.0 MB 5.9 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/10.0 MB 5.7 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/10.0 MB 6.2 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/10.0 MB 6.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/10.0 MB 5.9 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/10.0 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 5.2 MB/s eta 0:00:00
# Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Downloading Pillow-9.2.0-cp310-cp310-win_amd64.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ------------ --------------------------- 1.0/3.3 MB 10.1 MB/s eta 0:00:01
#    ------------ --------------------------- 1.0/3.3 MB 10.1 MB/s eta 0:00:01
#    ------------ --------------------------- 1.0/3.3 MB 10.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.8/3.3 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 3.1 MB/s eta 0:00:00
# Downloading pip-21.3.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 9.4 MB/s eta 0:00:00
# Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
# Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Downloading pyinstaller-5.5-py3-none-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 6.7 MB/s eta 0:00:00
# Downloading pyinstaller_hooks_contrib-2022.10-py2.py3-none-any.whl (244 kB)
# Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Downloading pytz-2022.4-py2.py3-none-any.whl (500 kB)
# Downloading pywin32_ctypes-0.2.0-py2.py3-none-any.whl (28 kB)
# Downloading requests-2.28.1-py3-none-any.whl (62 kB)
# Downloading scikit_learn-1.1.3-cp310-cp310-win_amd64.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.5 MB 10.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.5/7.5 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.6/7.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 9.9 MB/s eta 0:00:00
# Downloading scipy-1.9.1-cp310-cp310-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    - -------------------------------------- 1.0/38.6 MB 7.2 MB/s eta 0:00:06
#    -- ------------------------------------- 2.1/38.6 MB 4.5 MB/s eta 0:00:09
#    --- ------------------------------------ 3.1/38.6 MB 4.9 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.2/38.6 MB 5.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 5.2/38.6 MB 5.4 MB/s eta 0:00:07
#    ------ --------------------------------- 6.3/38.6 MB 5.4 MB/s eta 0:00:07
#    ------- -------------------------------- 7.3/38.6 MB 5.1 MB/s eta 0:00:07
#    ------- -------------------------------- 7.3/38.6 MB 5.1 MB/s eta 0:00:07
#    ------- -------------------------------- 7.3/38.6 MB 5.1 MB/s eta 0:00:07
#    ------- -------------------------------- 7.3/38.6 MB 5.1 MB/s eta 0:00:07
#    ------- -------------------------------- 7.3/38.6 MB 5.1 MB/s eta 0:00:07
#    -------- ------------------------------- 8.4/38.6 MB 3.3 MB/s eta 0:00:10
#    -------- ------------------------------- 8.4/38.6 MB 3.3 MB/s eta 0:00:10
#    -------- ------------------------------- 8.7/38.6 MB 2.9 MB/s eta 0:00:11
#    --------- ------------------------------ 9.4/38.6 MB 3.0 MB/s eta 0:00:10
#    ---------- ----------------------------- 10.5/38.6 MB 3.1 MB/s eta 0:00:10
#    ----------- ---------------------------- 11.5/38.6 MB 3.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 11.5/38.6 MB 3.2 MB/s eta 0:00:09
#    ------------ --------------------------- 11.8/38.6 MB 2.9 MB/s eta 0:00:10
#    ------------- -------------------------- 13.1/38.6 MB 3.0 MB/s eta 0:00:09
#    -------------- ------------------------- 13.6/38.6 MB 3.1 MB/s eta 0:00:08
#    --------------- ------------------------ 14.7/38.6 MB 3.2 MB/s eta 0:00:08
#    ---------------- ----------------------- 15.7/38.6 MB 3.2 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.8/38.6 MB 3.3 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.8/38.6 MB 3.3 MB/s eta 0:00:07
#    ------------------ --------------------- 17.6/38.6 MB 3.2 MB/s eta 0:00:07
#    ------------------- -------------------- 18.6/38.6 MB 3.2 MB/s eta 0:00:07
#    -------------------- ------------------- 19.9/38.6 MB 3.3 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.2/38.6 MB 3.4 MB/s eta 0:00:06
#    ---------------------- ----------------- 22.0/38.6 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.0/38.6 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.0/38.6 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.0/38.6 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.0/38.6 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.0/38.6 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.0/38.6 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.0/38.6 MB 3.5 MB/s eta 0:00:05
#    ----------------------- ---------------- 23.1/38.6 MB 2.9 MB/s eta 0:00:06
#    ------------------------ --------------- 23.3/38.6 MB 2.8 MB/s eta 0:00:06
#    ------------------------- -------------- 24.6/38.6 MB 2.9 MB/s eta 0:00:05
#    -------------------------- ------------- 25.2/38.6 MB 2.9 MB/s eta 0:00:05
#    --------------------------- ------------ 26.2/38.6 MB 2.9 MB/s eta 0:00:05
#    ---------------------------- ----------- 27.0/38.6 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.3/38.6 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.3/38.6 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.3/38.6 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.8/38.6 MB 2.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.6/38.6 MB 2.8 MB/s eta 0:00:04
#    ------------------------------ --------- 29.4/38.6 MB 2.8 MB/s eta 0:00:04
#    ------------------------------- -------- 30.4/38.6 MB 2.9 MB/s eta 0:00:03
#    ------------------------------- -------- 30.4/38.6 MB 2.9 MB/s eta 0:00:03
#    ------------------------------- -------- 30.7/38.6 MB 2.8 MB/s eta 0:00:03
#    -------------------------------- ------- 31.5/38.6 MB 2.8 MB/s eta 0:00:03
#    --------------------------------- ------ 32.5/38.6 MB 2.9 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.3/38.6 MB 2.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.6/38.6 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------ --- 34.9/38.6 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 36.4/38.6 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 3.0 MB/s eta 0:00:00
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ---------------------------------------- 0.0/953.1 kB ? eta -:--:--
#    ---------------------------------------- 953.1/953.1 kB 7.4 MB/s eta 0:00:00
# Downloading soundfile-0.11.0-py2.py3-none-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 9.6 MB/s eta 0:00:00
# Downloading statsmodels-0.13.2-cp310-cp310-win_amd64.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.1 MB 10.1 MB/s eta 0:00:01
#    --------- ------------------------------ 2.1/9.1 MB 6.5 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.1 MB 5.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.9/9.1 MB 4.5 MB/s eta 0:00:02
#    ------------------- -------------------- 4.5/9.1 MB 4.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.2/9.1 MB 4.4 MB/s eta 0:00:01
#    --------------------------- ------------ 6.3/9.1 MB 4.3 MB/s eta 0:00:01
#    -------------------------------- ------- 7.3/9.1 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  8.9/9.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 4.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
# Downloading wfdb-3.4.0-py3-none-any.whl (137 kB)
# Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Downloading whichcraft-0.6.1-py2.py3-none-any.whl (5.2 kB)
# Downloading zope.event-4.5.0-py2.py3-none-any.whl (6.8 kB)
# Building wheels for collected packages: bottle-websocket, dotteddict, Eel, future, parallel-map, pefile, zope.interface
#   Building wheel for bottle-websocket (pyproject.toml): started
#   Building wheel for bottle-websocket (pyproject.toml): finished with status 'done'
#   Created wheel for bottle-websocket: filename=bottle_websocket-0.2.9-py3-none-any.whl size=2342 sha256=e37e0a82f8511535e7b8cdd75181d1e335260ced323c0d27a46f5cd6649db7f6
#   Stored in directory: c:\users\ana.sofia.oliveira\appdata\local\pip\cache\wheels\d2\9c\7d\5cc2fe1ff85ad654a0e86d72d1706a97ef15db2200b83c98d6
#   Building wheel for dotteddict (pyproject.toml): started
#   Building wheel for dotteddict (pyproject.toml): finished with status 'done'
#   Created wheel for dotteddict: filename=dotteddict-2016.3.11-py2.py3-none-any.whl size=3275 sha256=10dacbc1339d4548941ac7f85addec518910d41b570ded619eaf53a40164bb66
#   Stored in directory: c:\users\ana.sofia.oliveira\appdata\local\pip\cache\wheels\f2\c8\c1\1b09c392549c50c4ed3809951deb63ba6d20798d5a1add9fe7
#   Building wheel for Eel (pyproject.toml): started
#   Building wheel for Eel (pyproject.toml): finished with status 'done'
#   Created wheel for Eel: filename=Eel-0.14.0-py3-none-any.whl size=17489 sha256=c32b55b6b8656af9a60b56782d7365bf355559cd487c1811a086d99b08a748f3
#   Stored in directory: c:\users\ana.sofia.oliveira\appdata\local\pip\cache\wheels\5a\22\db\6e4ab5a6f105d4404fce7e17b453aa2ae920c70b04ac8ed294
#   Building wheel for future (pyproject.toml): started
#   Building wheel for future (pyproject.toml): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491086 sha256=1d8cb666d20f9bccb1ac43393d4e882a5a87369e8f94346a88497cc828ec3e9e
#   Stored in directory: c:\users\ana.sofia.oliveira\appdata\local\pip\cache\wheels\22\73\06\557dc4f4ef68179b9d763930d6eec26b88ed7c389b19588a1c
#   Building wheel for parallel-map (pyproject.toml): started
#   Building wheel for parallel-map (pyproject.toml): finished with status 'done'
#   Created wheel for parallel-map: filename=parallel_map-0.2.1-py3-none-any.whl size=4647 sha256=b884400b3f2ce00fa2c593b82ca4d4e8cafaffca35ac39f778a02727a772f7a5
#   Stored in directory: c:\users\ana.sofia.oliveira\appdata\local\pip\cache\wheels\65\a6\0e\d05f4547ab79dc6a1abfa672ea8e8831ee8f82e7c8ae13cd7f
#   Building wheel for pefile (pyproject.toml): started
#   Building wheel for pefile (pyproject.toml): finished with status 'done'
#   Created wheel for pefile: filename=pefile-2022.5.30-py3-none-any.whl size=69375 sha256=7a1112e76f55c26b2ca9c12e5b9edc902ddab0fc31d50a4fc58a6921cde7ce84
#   Stored in directory: c:\users\ana.sofia.oliveira\appdata\local\pip\cache\wheels\eb\60\37\ee40403cbd895ccdb57eb28b03b0afabeb449d5df9ce776a0d
#   Building wheel for zope.interface (pyproject.toml): started
#   Building wheel for zope.interface (pyproject.toml): finished with status 'done'
#   Created wheel for zope.interface: filename=zope.interface-5.4.0-cp310-cp310-win_amd64.whl size=197652 sha256=db91a860dbd10a23d11c6fe486100d7d3228911ee64ea9c22241412a996ab588
#   Stored in directory: c:\users\ana.sofia.oliveira\appdata\local\pip\cache\wheels\21\a9\8b\0bfc5594d8e109d5b25d6b69e0cff14d09d93e3522dcb16d2b
# Successfully built bottle-websocket dotteddict Eel future parallel-map pefile zope.interface
# Installing collected packages: whichcraft, pywin32-ctypes, pytz, parallel-map, dotteddict, dotmap, bottle, boltons, appdirs, altgraph, wheel, urllib3, threadpoolctl, setuptools, python-dateutil, pyparsing, pyinstaller-hooks-contrib, pycparser, pip, Pillow, numpy, MarkupSafe, kiwisolver, joblib, idna, greenlet, future, fonttools, face, cycler, colorama, charset-normalizer, chardet, certifi, attrs, zope.interface, zope.event, tqdm, scipy, requests, pefile, patsy, pandas, packaging, Jinja2, glom, contourpy, cffi, statsmodels, soundfile, scikit-learn, pyinstaller, pooch, matplotlib, gevent, wfdb, mpldatacursor, mne, heartpy, gevent-websocket, bottle-websocket, Eel, auto-py-to-exe, pyPPG
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.6
#     Uninstalling colorama-0.4.6:
#       Successfully uninstalled colorama-0.4.6
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
# Successfully installed Eel-0.14.0 Jinja2-3.1.2 MarkupSafe-2.1.1 Pillow-9.2.0 altgraph-0.17.3 appdirs-1.4.4 attrs-22.1.0 auto-py-to-exe-2.23.1 boltons-21.0.0 bottle-0.12.23 bottle-websocket-0.2.9 certifi-2022.9.24 cffi-1.15.1 chardet-5.0.0 charset-normalizer-2.1.1 colorama-0.4.5 contourpy-1.0.5 cycler-0.11.0 dotmap-1.3.30 dotteddict-2016.3.11 face-20.1.1 fonttools-4.37.1 future-0.18.2 gevent-21.12.0 gevent-websocket-0.10.1 glom-22.1.0 greenlet-1.1.3 heartpy-1.2.7 idna-3.4 joblib-1.2.0 kiwisolver-1.4.4 matplotlib-3.6.1 mne-1.5.0 mpldatacursor-0.7.1 numpy-1.23.2 packaging-21.3 pandas-1.4.4 parallel-map-0.2.1 patsy-0.5.3 pefile-2022.5.30 pip-21.3.1 pooch-1.6.0 pyPPG-1.0.41 pycparser-2.21 pyinstaller-5.5 pyinstaller-hooks-contrib-2022.10 pyparsing-3.0.9 python-dateutil-2.8.2 pytz-2022.4 pywin32-ctypes-0.2.0 requests-2.28.1 scikit-learn-1.1.3 scipy-1.9.1 setuptools-60.2.0 soundfile-0.11.0 statsmodels-0.13.2 threadpoolctl-3.1.0 tqdm-4.64.1 urllib3-1.26.12 wfdb-3.4.0 wheel-0.37.1 whichcraft-0.6.1 zope.event-4.5.0 zope.interface-5.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyPPG import PPG, Fiducials, Biomarkers
from pyPPG.datahandling import load_data, plot_fiducials, save_data
import pyPPG.preproc as PP
import pyPPG.fiducials as FP
import pyPPG.biomarkers as BM
import pyPPG.ppg_sqi as SQI


import numpy as np
import sys
import json
import pandas as pd

# %%
data_path = "bidmc_data.mat" # the path of the file containing the PPG signal to be analysed
start_sig = 0 # the first sample of the signal to be analysed
end_sig = -1 # the last sample of the signal to be analysed (here a value of '-1' indicates the last sample)
savingfolder = 'temp_dir'
savingformat = 'csv'

# %%
signal = load_data(data_path=data_path, start_sig=start_sig, end_sig=end_sig)
print(signal.__dict__)
#signal.v = signal.v [0:20*signal.fs] # 20 second long signal to be analysed
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 signal = load_data(data_path=data_path, start_sig=start_sig, end_sig=end_sig)
#       2 print(signal.__dict__)
#       3 #signal.v = signal.v [0:20*signal.fs] # 20 second long signal to be analysed
#
# File c:\Users\ana.sofia.oliveira\Documents\ISEL\SB2425\.venv\lib\site-packages\pyPPG\datahandling.py:72, in load_data(data_path, fs, start_sig, end_sig, channel, use_tk)
#      70 if sig_format=='mat':
#      71     input_sig = scipy.io.loadmat(sig_path)
# ---> 72     sig = np.float64(np.squeeze(input_sig.get("Data")))[0:]
#      73     try:
#      74         fs = np.squeeze(input_sig.get("Fs"))
#
# IndexError: invalid index to scalar variable.

# %%
pip install biosppy
# Out:
# Collecting biosppy
#   Downloading biosppy-2.2.2-py2.py3-none-any.whl (149 kB)
# Requirement already satisfied: joblib in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from biosppy) (1.2.0)
# Requirement already satisfied: scikit-learn in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from biosppy) (1.1.3)
# Collecting h5py
#   Downloading h5py-3.12.1-cp310-cp310-win_amd64.whl (3.0 MB)
# Requirement already satisfied: matplotlib in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from biosppy) (3.6.1)
# Requirement already satisfied: scipy in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from biosppy) (1.9.1)
# Collecting pywavelets
#   Downloading pywavelets-1.7.0-cp310-cp310-win_amd64.whl (4.3 MB)
# Requirement already satisfied: numpy in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from biosppy) (1.23.2)
# Collecting shortuuid
#   Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Collecting mock
#   Downloading mock-5.1.0-py3-none-any.whl (30 kB)
# Collecting bidict
#   Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Requirement already satisfied: six in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from biosppy) (1.16.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from matplotlib->biosppy) (4.37.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from matplotlib->biosppy) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from matplotlib->biosppy) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from matplotlib->biosppy) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from matplotlib->biosppy) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from matplotlib->biosppy) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from matplotlib->biosppy) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from matplotlib->biosppy) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ana.sofia.oliveira\documents\isel\sb2425\.venv\lib\site-packages (from scikit-learn->biosppy) (3.1.0)
# Installing collected packages: shortuuid, pywavelets, opencv-python, mock, h5py, bidict, biosppy
# Successfully installed bidict-0.23.1 biosppy-2.2.2 h5py-3.12.1 mock-5.1.0 opencv-python-4.10.0.84 pywavelets-1.7.0 shortuuid-1.0.13
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\ana.sofia.oliveira\Documents\ISEL\SB2425\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import os
import shutil
import pandas as pd
from pathlib import Path
import numpy as np
import wfdb
import matplotlib.pyplot as plt
from biosppy.signals import ecg
from biosppy.signals import ppg

# %% [markdown]
# ### Creating dataset structure
# - Ler records no ficheiro RECORDS.txt
# - Ler records
# - Guardar todos os records num ficheiro HDF5 com fs, recordID, sinal

# %%
database_folder = Path('bidmc-ppg-and-respiration-dataset-1.0.0')
target_source = os.path.join(database_folder.parent.parent, 'ppg_dataset/all')

print(database_folder, target_source)

for file in os.listdir(database_folder):
    if(not os.path.isdir(file) and len(file.split('_')) == 1 ):
        filename = file.split(".")[0]
        with open(os.path.join(database_folder, file), 'w') as f:
            origin = os.path.join(database_folder, file)
            target = os.path.join(target_source, file)
            
            if(not os.path.isdir(target_source)):
                os.mkdir(target_source)
                
            shutil.copy2(origin, target)
            print("File", filename, "was copied to", target_source)
# Out:
# bidmc-ppg-and-respiration-dataset-1.0.0 .\ppg_dataset/all
# File ANNOTATORS was copied to .\ppg_dataset/all
# File bidmc01 was copied to .\ppg_dataset/all
# File bidmc01 was copied to .\ppg_dataset/all
# File bidmc01 was copied to .\ppg_dataset/all
# File bidmc01n was copied to .\ppg_dataset/all
# File bidmc01n was copied to .\ppg_dataset/all
# File bidmc02 was copied to .\ppg_dataset/all
# File bidmc02 was copied to .\ppg_dataset/all
# File bidmc02 was copied to .\ppg_dataset/all
# File bidmc02n was copied to .\ppg_dataset/all
# File bidmc02n was copied to .\ppg_dataset/all
# File bidmc03 was copied to .\ppg_dataset/all
# File bidmc03 was copied to .\ppg_dataset/all
# File bidmc03 was copied to .\ppg_dataset/all
# File bidmc03n was copied to .\ppg_dataset/all
# File bidmc03n was copied to .\ppg_dataset/all
# File bidmc04 was copied to .\ppg_dataset/all
# File bidmc04 was copied to .\ppg_dataset/all
# File bidmc04 was copied to .\ppg_dataset/all
# File bidmc04n was copied to .\ppg_dataset/all
# File bidmc04n was copied to .\ppg_dataset/all
# File bidmc05 was copied to .\ppg_dataset/all
# File bidmc05 was copied to .\ppg_dataset/all
# File bidmc05 was copied to .\ppg_dataset/all
# File bidmc05n was copied to .\ppg_dataset/all
# File bidmc05n was copied to .\ppg_dataset/all
# File bidmc06 was copied to .\ppg_dataset/all
# File bidmc06 was copied to .\ppg_dataset/all
# File bidmc06 was copied to .\ppg_dataset/all
# File bidmc06n was copied to .\ppg_dataset/all
# File bidmc06n was copied to .\ppg_dataset/all
# File bidmc07 was copied to .\ppg_dataset/all
# File bidmc07 was copied to .\ppg_dataset/all
# File bidmc07 was copied to .\ppg_dataset/all
# File bidmc07n was copied to .\ppg_dataset/all
# File bidmc07n was copied to .\ppg_dataset/all
# File bidmc08 was copied to .\ppg_dataset/all
# File bidmc08 was copied to .\ppg_dataset/all
# File bidmc08 was copied to .\ppg_dataset/all
# File bidmc08n was copied to .\ppg_dataset/all
# File bidmc08n was copied to .\ppg_dataset/all
# File bidmc09 was copied to .\ppg_dataset/all
# File bidmc09 was copied to .\ppg_dataset/all
# File bidmc09 was copied to .\ppg_dataset/all
# File bidmc09n was copied to .\ppg_dataset/all
# File bidmc09n was copied to .\ppg_dataset/all
# File bidmc10 was copied to .\ppg_dataset/all
# File bidmc10 was copied to .\ppg_dataset/all
# File bidmc10 was copied to .\ppg_dataset/all
# File bidmc10n was copied to .\ppg_dataset/all
# File bidmc10n was copied to .\ppg_dataset/all
# File bidmc11 was copied to .\ppg_dataset/all
# File bidmc11 was copied to .\ppg_dataset/all
# File bidmc11 was copied to .\ppg_dataset/all
# File bidmc11n was copied to .\ppg_dataset/all
# File bidmc11n was copied to .\ppg_dataset/all
# File bidmc12 was copied to .\ppg_dataset/all
# File bidmc12 was copied to .\ppg_dataset/all
# File bidmc12 was copied to .\ppg_dataset/all
# File bidmc12n was copied to .\ppg_dataset/all
# File bidmc12n was copied to .\ppg_dataset/all
# File bidmc13 was copied to .\ppg_dataset/all
# File bidmc13 was copied to .\ppg_dataset/all
# File bidmc13 was copied to .\ppg_dataset/all
# File bidmc13n was copied to .\ppg_dataset/all
# File bidmc13n was copied to .\ppg_dataset/all
# File bidmc14 was copied to .\ppg_dataset/all
# File bidmc14 was copied to .\ppg_dataset/all
# File bidmc14 was copied to .\ppg_dataset/all
# File bidmc14n was copied to .\ppg_dataset/all
# File bidmc14n was copied to .\ppg_dataset/all
# File bidmc15 was copied to .\ppg_dataset/all
# File bidmc15 was copied to .\ppg_dataset/all
# File bidmc15 was copied to .\ppg_dataset/all
# File bidmc15n was copied to .\ppg_dataset/all
# File bidmc15n was copied to .\ppg_dataset/all
# File bidmc16 was copied to .\ppg_dataset/all
# File bidmc16 was copied to .\ppg_dataset/all
# File bidmc16 was copied to .\ppg_dataset/all
# File bidmc16n was copied to .\ppg_dataset/all
# File bidmc16n was copied to .\ppg_dataset/all
# File bidmc17 was copied to .\ppg_dataset/all
# File bidmc17 was copied to .\ppg_dataset/all
# File bidmc17 was copied to .\ppg_dataset/all
# File bidmc17n was copied to .\ppg_dataset/all
# File bidmc17n was copied to .\ppg_dataset/all
# File bidmc18 was copied to .\ppg_dataset/all
# File bidmc18 was copied to .\ppg_dataset/all
# File bidmc18 was copied to .\ppg_dataset/all
# File bidmc18n was copied to .\ppg_dataset/all
# File bidmc18n was copied to .\ppg_dataset/all
# File bidmc19 was copied to .\ppg_dataset/all
# File bidmc19 was copied to .\ppg_dataset/all
# File bidmc19 was copied to .\ppg_dataset/all
# File bidmc19n was copied to .\ppg_dataset/all
# File bidmc19n was copied to .\ppg_dataset/all
# File bidmc20 was copied to .\ppg_dataset/all
# File bidmc20 was copied to .\ppg_dataset/all
# File bidmc20 was copied to .\ppg_dataset/all
# File bidmc20n was copied to .\ppg_dataset/all
# File bidmc20n was copied to .\ppg_dataset/all
# File bidmc21 was copied to .\ppg_dataset/all
# File bidmc21 was copied to .\ppg_dataset/all
# File bidmc21 was copied to .\ppg_dataset/all
# File bidmc21n was copied to .\ppg_dataset/all
# File bidmc21n was copied to .\ppg_dataset/all
# File bidmc22 was copied to .\ppg_dataset/all
# File bidmc22 was copied to .\ppg_dataset/all
# File bidmc22 was copied to .\ppg_dataset/all
# File bidmc22n was copied to .\ppg_dataset/all
# File bidmc22n was copied to .\ppg_dataset/all
# File bidmc23 was copied to .\ppg_dataset/all
# File bidmc23 was copied to .\ppg_dataset/all
# File bidmc23 was copied to .\ppg_dataset/all
# File bidmc23n was copied to .\ppg_dataset/all
# File bidmc23n was copied to .\ppg_dataset/all
# File bidmc24 was copied to .\ppg_dataset/all
# File bidmc24 was copied to .\ppg_dataset/all
# File bidmc24 was copied to .\ppg_dataset/all
# File bidmc24n was copied to .\ppg_dataset/all
# File bidmc24n was copied to .\ppg_dataset/all
# File bidmc25 was copied to .\ppg_dataset/all
# File bidmc25 was copied to .\ppg_dataset/all
# File bidmc25 was copied to .\ppg_dataset/all
# File bidmc25n was copied to .\ppg_dataset/all
# File bidmc25n was copied to .\ppg_dataset/all
# File bidmc26 was copied to .\ppg_dataset/all
# File bidmc26 was copied to .\ppg_dataset/all
# File bidmc26 was copied to .\ppg_dataset/all
# File bidmc26n was copied to .\ppg_dataset/all
# File bidmc26n was copied to .\ppg_dataset/all
# File bidmc27 was copied to .\ppg_dataset/all
# File bidmc27 was copied to .\ppg_dataset/all
# File bidmc27 was copied to .\ppg_dataset/all
# File bidmc27n was copied to .\ppg_dataset/all
# File bidmc27n was copied to .\ppg_dataset/all
# File bidmc28 was copied to .\ppg_dataset/all
# File bidmc28 was copied to .\ppg_dataset/all
# File bidmc28 was copied to .\ppg_dataset/all
# File bidmc28n was copied to .\ppg_dataset/all
# File bidmc28n was copied to .\ppg_dataset/all
# File bidmc29 was copied to .\ppg_dataset/all
# File bidmc29 was copied to .\ppg_dataset/all
# File bidmc29 was copied to .\ppg_dataset/all
# File bidmc29n was copied to .\ppg_dataset/all
# File bidmc29n was copied to .\ppg_dataset/all
# File bidmc30 was copied to .\ppg_dataset/all
# File bidmc30 was copied to .\ppg_dataset/all
# File bidmc30 was copied to .\ppg_dataset/all
# File bidmc30n was copied to .\ppg_dataset/all
# File bidmc30n was copied to .\ppg_dataset/all
# File bidmc31 was copied to .\ppg_dataset/all
# File bidmc31 was copied to .\ppg_dataset/all
# File bidmc31 was copied to .\ppg_dataset/all
# File bidmc31n was copied to .\ppg_dataset/all
# File bidmc31n was copied to .\ppg_dataset/all
# File bidmc32 was copied to .\ppg_dataset/all
# File bidmc32 was copied to .\ppg_dataset/all
# File bidmc32 was copied to .\ppg_dataset/all
# File bidmc32n was copied to .\ppg_dataset/all
# File bidmc32n was copied to .\ppg_dataset/all
# File bidmc33 was copied to .\ppg_dataset/all
# File bidmc33 was copied to .\ppg_dataset/all
# File bidmc33 was copied to .\ppg_dataset/all
# File bidmc33n was copied to .\ppg_dataset/all
# File bidmc33n was copied to .\ppg_dataset/all
# File bidmc34 was copied to .\ppg_dataset/all
# File bidmc34 was copied to .\ppg_dataset/all
# File bidmc34 was copied to .\ppg_dataset/all
# File bidmc34n was copied to .\ppg_dataset/all
# File bidmc34n was copied to .\ppg_dataset/all
# File bidmc35 was copied to .\ppg_dataset/all
# File bidmc35 was copied to .\ppg_dataset/all
# File bidmc35 was copied to .\ppg_dataset/all
# File bidmc35n was copied to .\ppg_dataset/all
# File bidmc35n was copied to .\ppg_dataset/all
# File bidmc36 was copied to .\ppg_dataset/all
# File bidmc36 was copied to .\ppg_dataset/all
# File bidmc36 was copied to .\ppg_dataset/all
# File bidmc36n was copied to .\ppg_dataset/all
# File bidmc36n was copied to .\ppg_dataset/all
# File bidmc37 was copied to .\ppg_dataset/all
# File bidmc37 was copied to .\ppg_dataset/all
# File bidmc37 was copied to .\ppg_dataset/all
# File bidmc37n was copied to .\ppg_dataset/all
# File bidmc37n was copied to .\ppg_dataset/all
# File bidmc38 was copied to .\ppg_dataset/all
# File bidmc38 was copied to .\ppg_dataset/all
# File bidmc38 was copied to .\ppg_dataset/all
# File bidmc38n was copied to .\ppg_dataset/all
# File bidmc38n was copied to .\ppg_dataset/all
# File bidmc39 was copied to .\ppg_dataset/all
# File bidmc39 was copied to .\ppg_dataset/all
# File bidmc39 was copied to .\ppg_dataset/all
# File bidmc39n was copied to .\ppg_dataset/all
# File bidmc39n was copied to .\ppg_dataset/all
# File bidmc40 was copied to .\ppg_dataset/all
# File bidmc40 was copied to .\ppg_dataset/all
# File bidmc40 was copied to .\ppg_dataset/all
# File bidmc40n was copied to .\ppg_dataset/all
# File bidmc40n was copied to .\ppg_dataset/all
# File bidmc41 was copied to .\ppg_dataset/all
# File bidmc41 was copied to .\ppg_dataset/all
# File bidmc41 was copied to .\ppg_dataset/all
# File bidmc41n was copied to .\ppg_dataset/all
# File bidmc41n was copied to .\ppg_dataset/all
# File bidmc42 was copied to .\ppg_dataset/all
# File bidmc42 was copied to .\ppg_dataset/all
# File bidmc42 was copied to .\ppg_dataset/all
# File bidmc42n was copied to .\ppg_dataset/all
# File bidmc42n was copied to .\ppg_dataset/all
# File bidmc43 was copied to .\ppg_dataset/all
# File bidmc43 was copied to .\ppg_dataset/all
# File bidmc43 was copied to .\ppg_dataset/all
# File bidmc43n was copied to .\ppg_dataset/all
# File bidmc43n was copied to .\ppg_dataset/all
# File bidmc44 was copied to .\ppg_dataset/all
# File bidmc44 was copied to .\ppg_dataset/all
# File bidmc44 was copied to .\ppg_dataset/all
# File bidmc44n was copied to .\ppg_dataset/all
# File bidmc44n was copied to .\ppg_dataset/all
# File bidmc45 was copied to .\ppg_dataset/all
# File bidmc45 was copied to .\ppg_dataset/all
# File bidmc45 was copied to .\ppg_dataset/all
# File bidmc45n was copied to .\ppg_dataset/all
# File bidmc45n was copied to .\ppg_dataset/all
# File bidmc46 was copied to .\ppg_dataset/all
# File bidmc46 was copied to .\ppg_dataset/all
# File bidmc46 was copied to .\ppg_dataset/all
# File bidmc46n was copied to .\ppg_dataset/all
# File bidmc46n was copied to .\ppg_dataset/all
# File bidmc47 was copied to .\ppg_dataset/all
# File bidmc47 was copied to .\ppg_dataset/all
# File bidmc47 was copied to .\ppg_dataset/all
# File bidmc47n was copied to .\ppg_dataset/all
# File bidmc47n was copied to .\ppg_dataset/all
# File bidmc48 was copied to .\ppg_dataset/all
# File bidmc48 was copied to .\ppg_dataset/all
# File bidmc48 was copied to .\ppg_dataset/all
# File bidmc48n was copied to .\ppg_dataset/all
# File bidmc48n was copied to .\ppg_dataset/all
# File bidmc49 was copied to .\ppg_dataset/all
# File bidmc49 was copied to .\ppg_dataset/all
# File bidmc49 was copied to .\ppg_dataset/all
# File bidmc49n was copied to .\ppg_dataset/all
# File bidmc49n was copied to .\ppg_dataset/all
# File bidmc50 was copied to .\ppg_dataset/all
# File bidmc50 was copied to .\ppg_dataset/all
# File bidmc50 was copied to .\ppg_dataset/all
# File bidmc50n was copied to .\ppg_dataset/all
# File bidmc50n was copied to .\ppg_dataset/all
# File bidmc51 was copied to .\ppg_dataset/all
# File bidmc51 was copied to .\ppg_dataset/all
# File bidmc51 was copied to .\ppg_dataset/all
# File bidmc51n was copied to .\ppg_dataset/all
# File bidmc51n was copied to .\ppg_dataset/all
# File bidmc52 was copied to .\ppg_dataset/all
# File bidmc52 was copied to .\ppg_dataset/all
# File bidmc52 was copied to .\ppg_dataset/all
# File bidmc52n was copied to .\ppg_dataset/all
# File bidmc52n was copied to .\ppg_dataset/all
# File bidmc53 was copied to .\ppg_dataset/all
# File bidmc53 was copied to .\ppg_dataset/all
# File bidmc53 was copied to .\ppg_dataset/all
# File bidmc53n was copied to .\ppg_dataset/all
# File bidmc53n was copied to .\ppg_dataset/all
# File DBS was copied to .\ppg_dataset/all
# File LICENSE was copied to .\ppg_dataset/all
# File README was copied to .\ppg_dataset/all
# File RECORDS was copied to .\ppg_dataset/all
# File SHA256SUMS was copied to .\ppg_dataset/all

# %% [markdown]
# ### Reading all PPG sinals from dataset
# - Ler sinais do ficheiro HDF5

# %%
ppgs = None
labels = []
frequencies = []
individuos = 53

data = []

for i in range(1, individuos):
    record_name = f"ppg_dataset/all/bidmc{str(i).zfill(2)}"
    print("Record name:", record_name)
    try:
        record, fields = wfdb.rdsamp(record_name)
        print("Atributos1:", fields)
        if ('PLETH,' in fields['sig_name']):
            ppg = record[:,fields['sig_name'].index('PLETH,')][np.newaxis]
            fs = fields['fs']
            if ppgs is None: 
                data.append({'subject': i, 
                             'signal': ppg,
                             'fs': fs})
                ppgs = ppg
                labels.append(i)
                print("->Adicionado sinal do individuo", i)
                continue
            
            ppgs = np.vstack((ppgs, ppg))
            labels.append(i)
            frequencies.append(fs)
            print("->Adicionado sinal do individuo", i)
    except Exception as e:
        print("Erro ao adicionar sinal do individuo", i, e)
# Out:
# Record name: ppg_dataset/all/bidmc01
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'V,', 'AVR,', 'II,'], 'comments': ['<age>: 88 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s01182/ <data segment>: 2688-03-25-23-14<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 1
# Record name: ppg_dataset/all/bidmc02
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['mV', 'NU', 'pm', 'mV', 'mV'], 'sig_name': ['II,', 'PLETH,', 'RESP,', 'V,', 'AVR,'], 'comments': ['<age>: 65 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s01241/ <data segment>: 3195-12-18-05-38<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 2
# Record name: ppg_dataset/all/bidmc03
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 6, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV', 'mmHg'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,', 'CVP,'], 'comments': ['<age>: 46 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s01795/ <data segment>: 2503-07-03-17-43<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 3
# Record name: ppg_dataset/all/bidmc04
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 6, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV', 'mmHg'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,', 'ABP,'], 'comments': ['<age>: 78 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s01840/ <data segment>: 3454-10-24-18-46<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 4
# Record name: ppg_dataset/all/bidmc05
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 73 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s01995/ <data segment>: 3123-12-10-15-38<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 5
# Record name: ppg_dataset/all/bidmc06
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 7, 'base_date': None, 'base_time': None, 'units': ['pm', 'mmHg', 'mmHg', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'ABP,', 'CVP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 64 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s03386/ <data segment>: 2577-07-30-13-04<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 6
# Record name: ppg_dataset/all/bidmc07
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 7, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV', 'mmHg', 'mmHg'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,', 'CVP,', 'ART,'], 'comments': ['<age>: 64 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s03386/ <data segment>: 2577-08-02-01-41<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 7
# Record name: ppg_dataset/all/bidmc08
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 7, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV', 'mmHg', 'mmHg'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,', 'ART,', 'CVP,'], 'comments': ['<age>: 64 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s03386/ <data segment>: 2577-08-03-12-35<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 8
# Record name: ppg_dataset/all/bidmc09
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 6, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV', 'mmHg'], 'sig_name': ['RESP,', 'PLETH,', 'I,', 'V,', 'II,', 'ABP,'], 'comments': ['<age>: 64 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s03386/ <data segment>: 2577-08-07-20-40<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 9
# Record name: ppg_dataset/all/bidmc10
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 6, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV', 'mmHg'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,', 'CVP,'], 'comments': ['<age>: 74 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s03516/ <data segment>: 3087-07-13-01-12<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 10
# Record name: ppg_dataset/all/bidmc11
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['NU', 'pm', 'mV', 'mV', 'mV'], 'sig_name': ['PLETH,', 'RESP,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 50 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s04641/ <data segment>: 3112-08-01-14-02<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 11
# Record name: ppg_dataset/all/bidmc12
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 75 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s06914/ <data segment>: 2530-02-22-13-21<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 12
# Record name: ppg_dataset/all/bidmc13
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 71 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s07432/ <data segment>: 3359-07-25-15-04<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 13
# Record name: ppg_dataset/all/bidmc14
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 70 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s07784/ <data segment>: 3115-08-30-15-19<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 14
# Record name: ppg_dataset/all/bidmc15
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'I,', 'MCL,', 'II,'], 'comments': ['<age>: 51 <sex>: M <location>: ccu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s08452/ <data segment>: 2862-12-24-16-10<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 15
# Record name: ppg_dataset/all/bidmc16
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 56 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s08915/ <data segment>: 3391-06-02-00-27<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 16
# Record name: ppg_dataset/all/bidmc17
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 72 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s08936/ <data segment>: 3043-07-05-18-01<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 17
# Record name: ppg_dataset/all/bidmc18
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['NU', 'pm', 'mV', 'mV', 'mV'], 'sig_name': ['PLETH,', 'RESP,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: NaN <sex>: ? <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s09483/ <data segment>: 3089-08-26-21-25<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 18
# Record name: ppg_dataset/all/bidmc19
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'mV', 'mV', 'mV', 'NU'], 'sig_name': ['RESP,', 'II,', 'V,', 'AVR,', 'PLETH,'], 'comments': ['<age>: 85 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s09968/ <data segment>: 2564-01-26-21-54<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 19
# Record name: ppg_dataset/all/bidmc20
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 44 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s11342/ <data segment>: 2777-07-19-19-33<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 20
# Record name: ppg_dataset/all/bidmc21
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 44 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s11342/ <data segment>: 2777-09-25-23-35<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 21
# Record name: ppg_dataset/all/bidmc22
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 7, 'base_date': None, 'base_time': None, 'units': ['pm', 'mmHg', 'NU', 'mV', 'mV', 'mV', 'mmHg'], 'sig_name': ['RESP,', 'ABP,', 'PLETH,', 'II,', 'V,', 'AVR,', 'CVP,'], 'comments': ['<age>: 44 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s11342/ <data segment>: 2777-09-28-13-38<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 22
# Record name: ppg_dataset/all/bidmc23
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 6, 'base_date': None, 'base_time': None, 'units': ['NU', 'mmHg', 'pm', 'mV', 'mV', 'mV'], 'sig_name': ['PLETH,', 'ABP,', 'RESP,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 44 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s11342/ <data segment>: 2777-09-30-12-41<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 23
# Record name: ppg_dataset/all/bidmc24
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 7, 'base_date': None, 'base_time': None, 'units': ['mmHg', 'pm', 'NU', 'mV', 'mV', 'mV', 'mmHg'], 'sig_name': ['ABP,', 'RESP,', 'PLETH,', 'V,', 'II,', 'AVR,', 'CVP,'], 'comments': ['<age>: 77 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s12531/ <data segment>: 3144-03-08-13-21<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 24
# Record name: ppg_dataset/all/bidmc25
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 74 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s12589/ <data segment>: 3365-11-16-23-47<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 25
# Record name: ppg_dataset/all/bidmc26
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 86 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s13314/ <data segment>: 2641-10-27-08-25<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 26
# Record name: ppg_dataset/all/bidmc27
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'mV', 'mV', 'mV', 'NU'], 'sig_name': ['RESP,', 'II,', 'V,', 'AVR,', 'PLETH,'], 'comments': ['<age>: 43 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s13927/ <data segment>: 3107-03-28-07-43<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 27
# Record name: ppg_dataset/all/bidmc28
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 6, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV', 'mmHg'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,', 'CVP,'], 'comments': ['<age>: 90+ <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s15646/ <data segment>: 3164-11-16-15-38<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 28
# Record name: ppg_dataset/all/bidmc29
# Erro ao adicionar sinal do individuo 29 list index out of range
# Record name: ppg_dataset/all/bidmc30
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'MCL,', 'AVR,'], 'comments': ['<age>: 48 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s17497/ <data segment>: 3491-10-08-12-20<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 30
# Record name: ppg_dataset/all/bidmc31
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 69 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s17735/ <data segment>: 3213-09-30-22-27<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 31
# Record name: ppg_dataset/all/bidmc32
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'mV', 'mV', 'mV', 'NU'], 'sig_name': ['RESP,', 'II,', 'V,', 'AVR,', 'PLETH,'], 'comments': ['<age>: 90+ <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s17756/ <data segment>: 2946-04-06-17-40<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 32
# Record name: ppg_dataset/all/bidmc33
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'mV', 'mV', 'mV', 'NU'], 'sig_name': ['RESP,', 'II,', 'V,', 'AVR,', 'PLETH,'], 'comments': ['<age>: 76 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s19981/ <data segment>: 3073-11-13-03-26<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 33
# Record name: ppg_dataset/all/bidmc34
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 57 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s20471/ <data segment>: 3007-09-29-22-15<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 34
# Record name: ppg_dataset/all/bidmc35
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 67 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s20486/ <data segment>: 2701-07-11-18-41<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 35
# Record name: ppg_dataset/all/bidmc36
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 57 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s22348/ <data segment>: 3321-06-15-15-40<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 36
# Record name: ppg_dataset/all/bidmc37
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'mV', 'mV', 'mV', 'NU'], 'sig_name': ['RESP,', 'II,', 'V,', 'AVR,', 'PLETH,'], 'comments': ['<age>: 70 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s24455/ <data segment>: 2864-01-04-04-24<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 37
# Record name: ppg_dataset/all/bidmc38
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'I,', 'MCL,', 'II,'], 'comments': ['<age>: 88 <sex>: F <location>: ccu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s25323/ <data segment>: 2591-11-25-02-37<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 38
# Record name: ppg_dataset/all/bidmc39
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['mV', 'pm', 'mV', 'mV', 'NU'], 'sig_name': ['I,', 'RESP,', 'II,', 'V,', 'PLETH,'], 'comments': ['<age>: 88 <sex>: F <location>: ccu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s25323/ <data segment>: 2591-11-25-12-05<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 39
# Record name: ppg_dataset/all/bidmc40
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'mV', 'mV', 'mV', 'NU'], 'sig_name': ['RESP,', 'II,', 'V,', 'AVR,', 'PLETH,'], 'comments': ['<age>: 26 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s26845/ <data segment>: 2509-08-28-22-49<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 40
# Record name: ppg_dataset/all/bidmc41
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 6, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV', 'mmHg'], 'sig_name': ['RESP,', 'PLETH,', 'I,', 'II,', 'V,', 'ABP,'], 'comments': ['<age>: 73 <sex>: F <location>: ccu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s26868/ <data segment>: 2926-03-22-14-16<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 41
# Record name: ppg_dataset/all/bidmc42
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['mV', 'pm', 'mV', 'mV', 'NU'], 'sig_name': ['V,', 'RESP,', 'II,', 'AVR,', 'PLETH,'], 'comments': ['<age>: 85 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s29093/ <data segment>: 2539-01-17-04-44<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 42
# Record name: ppg_dataset/all/bidmc43
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 19 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s29125/ <data segment>: 2893-05-13-16-26<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 43
# Record name: ppg_dataset/all/bidmc44
# Erro ao adicionar sinal do individuo 44 Samples were not loaded correctly
# Record name: ppg_dataset/all/bidmc45
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'mV', 'mV', 'mV', 'NU'], 'sig_name': ['RESP,', 'II,', 'V,', 'AVR,', 'PLETH,'], 'comments': ['<age>: 52 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s29622/ <data segment>: 3293-08-13-21-32<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 45
# Record name: ppg_dataset/all/bidmc46
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['NU', 'pm', 'mV', 'mV', 'mV'], 'sig_name': ['PLETH,', 'RESP,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 61 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s29866/ <data segment>: 2605-01-29-22-44<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 46
# Record name: ppg_dataset/all/bidmc47
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 6, 'base_date': None, 'base_time': None, 'units': ['pm', 'mmHg', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'ABP,', 'PLETH,', 'II,', 'III,', 'V,'], 'comments': ['<age>: 48 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s30026/ <data segment>: 3337-03-19-14-47<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 47
# Record name: ppg_dataset/all/bidmc48
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'mV', 'mV', 'mV', 'NU'], 'sig_name': ['RESP,', 'II,', 'V,', 'AVR,', 'PLETH,'], 'comments': ['<age>: 37 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s30243/ <data segment>: 3157-09-07-14-06<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 48
# Record name: ppg_dataset/all/bidmc49
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'NU', 'mV', 'mV', 'mV'], 'sig_name': ['RESP,', 'PLETH,', 'II,', 'MCL,', 'AVR,'], 'comments': ['<age>: 77 <sex>: M <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s31106/ <data segment>: 3080-07-14-23-40<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 49
# Record name: ppg_dataset/all/bidmc50
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['NU', 'pm', 'mV', 'mV', 'mV'], 'sig_name': ['PLETH,', 'RESP,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 67 <sex>: M <location>: ccu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s31141/ <data segment>: 2862-05-10-13-41<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 50
# Record name: ppg_dataset/all/bidmc51
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['pm', 'mV', 'mV', 'mV', 'NU'], 'sig_name': ['RESP,', 'II,', 'V,', 'AVR,', 'PLETH,'], 'comments': ['<age>: 78 <sex>: F <location>: ccu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s31400/ <data segment>: 2964-04-05-11-46<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 51
# Record name: ppg_dataset/all/bidmc52
# Atributos1: {'fs': 125, 'sig_len': 60001, 'n_sig': 5, 'base_date': None, 'base_time': None, 'units': ['NU', 'pm', 'mV', 'mV', 'mV'], 'sig_name': ['PLETH,', 'RESP,', 'II,', 'V,', 'AVR,'], 'comments': ['<age>: 29 <sex>: F <location>: micu <source>: https://physionet.org/physiobank/database/mimic2wdb/matched/s32195/ <data segment>: 2757-07-15-21-26<modifications>: this is not a verbatim copy of an original file. Please see the accompanying LICENSE.txt file for further details.']}
# ->Adicionado sinal do individuo 52

# %% [markdown]
# ### Sinais PPG de 3 indivíduos

# %% [markdown]
# - 53 registos com 8 minutos de duração por cada registo.
# - Sinais PPG amostrado a 125 Hz.
# - Sinais de batimento cardíaco (HR), ritmo respiratório (RR) e níveis de saturação do oxigénio no sangue (SpO2) amostrados a 1 Hz.

# %%
nSamples = 1
nIndividuos = 4
plt.plot(ppgs[:nIndividuos, 0:nSamples*fs].T);
plt.legend(labels[:nIndividuos]);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 nSamples = 1
#       2 nIndividuos = 4
# ----> 3 plt.plot(data.ppgs[:nIndividuos, 0:nSamples*fs].T);
#       4 plt.legend(labels[:nIndividuos]);
#
# AttributeError: 'list' object has no attribute 'ppgs'

# %% [markdown]
# ### Templates
# - Guardar os templates de cada record no ficheiro HDF5

# %%
templates = {'fs': fs, 'ppgs': ppgs, 'labels': labels, 'frequencies': frequencies}
for i in range(0, nIndividuos):
    out = ppg.ppg(signal=ppgs[i,:3000], sampling_rate=frequencies[i], show=True)
    print(out.keys())
# Out:
# ['ts', 'filtered', 'peaks', 'templates_ts', 'templates', 'heart_rate_ts', 'heart_rate']
# ['ts', 'filtered', 'peaks', 'templates_ts', 'templates', 'heart_rate_ts', 'heart_rate']
# ['ts', 'filtered', 'peaks', 'templates_ts', 'templates', 'heart_rate_ts', 'heart_rate']
# ['ts', 'filtered', 'peaks', 'templates_ts', 'templates', 'heart_rate_ts', 'heart_rate']

# %%
from biosppy.clustering import mdist_templates

# %%
biosppy.clustering.mdist_templates(data=None, clusters=None, ntemplates=1, metric='euclidean', metric_args=None)

# %% [markdown]
# - Peak detection
# - IBI detection - Inter-beat Intervals
# - HRV features based on IBI
